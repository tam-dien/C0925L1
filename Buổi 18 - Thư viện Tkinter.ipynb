# %% [markdown]
# # Tkinter
#
# ### Thư viện Tkinter là gì?
#
# Thư viện Tkinter là thư viện hỗ trợ chúng ta xây dựng GUI bằng python

# %% [markdown]
# ### Thêm thư viện
#
# Cú pháp:
#
# `from tkinter import *`
#
# <b> Thêm thư viện: </b>

# %%
# module
from tkinter import *

# %% [markdown]
# ### Khởi tạo cửa số
#
# Cú pháp:
#
# `<tên đối tượng> = Tk()`
#
# Đổi tiêu đề cửa số:
#
# `<tên đối tượng>.title("Tiêu đề mới")`
#
# ##### Lưu ý: ta cần thêm hàm `<tên đối tượng>.mainloop()` để cửa sổ hoạt động
#
# <b>Hãy khởi tạo một cửa sổ:</b>

# %%
from tkinter import *

screen = Tk()

screen.title("Đây là tiêu đề")

screen.mainloop()

# %% [markdown]
# ### Thêm widget cho cửa sổ
#
# Widget là những đối tượng sẽ hiển thị và hoạt động trên cửa số
#
# Có rất nhiều loại Widget như: nút nhấn (button), nhãn (label), khung nhập dữ liệu (Entry),...

# %% [markdown]
# ### Label
#
# Cú pháp:
#
# `<tên đối tượng> = Label(<cửa số>,text = <nội dung>)`
#
# ##### Lưu ý, ta cần dùng lệnh `<tên đối tượng>.pack()` để Label có thể hiển thị lên cửa sổ
#
# <b> Hãy thêm một đối tượng Label vào cửa sổ: </b>

# %%
from tkinter import *

screen = Tk()

screen.title("Đây là tiêu đề")
screen.geometry("300x300")

label = Label(screen, text="hello")
label.pack()

screen.mainloop()

# %%
from tkinter import *

screen = Tk()

screen.title("Đây là tiêu đề")
screen.geometry("300x300")

label = Label(screen, text="hello", fg="red")
label.pack()

screen.mainloop()

# %% [markdown]
# ### Button
#
# Cú pháp:
#
# `<tên đối tượng> = Button(<cửa số>,text = <nội dung>)`
#
# ##### Lưu ý, ta cần dùng lệnh `<tên đối tượng>.pack()` để Button có thể hiển thị lên cửa sổ
#
# <b> Hãy thêm một đối tượng Button vào cửa sổ: </b>

# %%
from tkinter import *

screen = Tk()

screen.title("Đây là tiêu đề")
screen.geometry("300x300")

label = Label(screen, text="hello", fg="#001e8a")
label.pack()

mau = 1
def click_me():
    global mau
    if mau == 1:
        label.config(fg="#bc1414")
        mau = 2
    else:
        label.config(fg="#001e8a")
        mau = 1

button = Button(screen, text="click me", command=click_me)
button.pack()

screen.mainloop()

# %%
from tkinter import *

screen = Tk()

screen.title("Đây là tiêu đề")
screen.geometry("300x300")

label_1 = Label(screen, text="hello", fg="#001e8a", bg="green", width=20, font=("Arial", 20))
label_1.pack()

label_2 = Label(screen, text="hello_2", fg="#001e8a", bg="green", width=20)
label_2.pack()

screen.mainloop()

# %% [markdown]
# ### Entry
#
# Cú pháp:
#
# `<tên đối tượng> = Entry(<cửa số>)`
#
# ##### Lưu ý, ta cần dùng lệnh `<tên đối tượng>.pack()` để Entry có thể hiển thị lên cửa sổ
#
# <b> Hãy thêm một đối tượng Entry vào cửa sổ: </b>

# %%
from tkinter import *

screen = Tk()

screen.title("Đây là tiêu đề")
screen.geometry("300x300")

entry_1 = Entry(screen)
entry_2 = Entry(screen)
label = Label(screen, text="")

def click_me():
    label.config(text=int(entry_1.get()) + int(entry_2.get()))

button = Button(screen, text="click me", command=click_me)
button.pack(side="top")
entry_1.pack(side="top")
entry_2.pack(side="top")
label.pack(side="top")

screen.mainloop()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# Cell In[9], line 8
#       5 screen.title("Đây là tiêu đề")
#       6 screen.geometry("300x300")
# ----> 8 entry_1 = Entry(screen, pady=3)
#       9 entry_2 = Entry(screen)
#      10 label = Label(screen, text="")
#
# File c:\Users\tamdi\miniconda3\envs\linhtinh\Lib\tkinter\__init__.py:3137, in Entry.__init__(self, master, cnf, **kw)
#    3126 def __init__(self, master=None, cnf={}, **kw):
#    3127     """Construct an entry widget with the parent MASTER.
#    3128
#    3129     Valid resource names: background, bd, bg, borderwidth, cursor,
#    (...)   3135     textvariable, validate, validatecommand, vcmd, width,
#    3136     xscrollcommand."""
# -> 3137     Widget.__init__(self, master, 'entry', cnf, kw)
#
# File c:\Users\tamdi\miniconda3\envs\linhtinh\Lib\tkinter\__init__.py:2661, in BaseWidget.__init__(self, master, widgetName, cnf, kw, extra)
#    2659 for k, v in classes:
#    2660     del cnf[k]
# -> 2661 self.tk.call(
#    2662     (widgetName, self._w) + extra + self._options(cnf))
#    2663 for k, v in classes:
#    2664     k.configure(self, v)
#
# TclError: unknown option "-pady"

# %% [markdown]
# ### pack()
#
# Lệnh `pack()` sẽ giúp sắp xếp các đối tượng theo thứ tự nhất định
#
# pack() có các tham số:
#
# - <b>expand</b>:  Tùy chọn này sẽ quyết định các widget có được mở rộng để lấp đầy bất kì khoảng trống thừa trong tống thể hình học hay không. Nó có các giá trị Boolean, True hoặc False, giá trị mặc định là False
# - <b>fill</b>: Nó được sử dụng để lấp đầy các khoảng trống thừa . Giá trị mặc định là NONE, và có giá định khác như X (lấp theo chiều ngang) , Y(lấp theo chiều dọc) hoặc BOTH (lấp theo chiều ngang và dọc)
# - <b>side</b>: Được sử dụng để chỉ hướng mặt của widget được đóng gói bên trong cửa sổ , có các giá trị TOP(mặc định) ,BOTTOM, LEFT hoặc RIGHT

# %% [markdown]
# <b>Hãy ứng dụng lệnh pack() để xây dựng cửa sổ sau:</b>
#
# ![image.png](attachment:image.png)

# %%
from tkinter import *

screen = Tk()

screen.title("Đây là tiêu đề")
screen.geometry("300x300")

entry_1 = Entry(screen)
entry_2 = Entry(screen)
label = Label(screen, text="hello", bg="blue")

def click_me():
    label.config(text=int(entry_1.get()) + int(entry_2.get()))

button = Button(screen, text="click me", command=click_me)
button.pack(side="top")
entry_1.pack(side="top")
entry_2.pack(side="top", pady=5, ipady=3)
label.pack(side="top", pady=3)

screen.mainloop()

# %%
from tkinter import *

screen = Tk()

screen.title("Login Screen")
screen.geometry("300x300")

label_1 = Label(screen, text="Please enter email and password to login")
label_2 = Label(screen, text="Username")
label_3 = Label(screen, text="Password")

username_entry = Entry(screen)
password_entry = Entry(screen)

def login():
    pass

button = Button(screen, text="Login", command=login)

label_1.pack()
label_2.pack()
username_entry.pack()
label_3.pack()
password_entry.pack()
button.pack()

screen.mainloop()

# %%
from tkinter import *

screen = Tk()

screen.title("tk")
screen.geometry("500x200")

label_1 = Label(screen, text="Please enter email and password to login")
label_2 = Label(screen, text="Username")

label_1.pack()
label_2.pack()

def click_me():
    label.config(fg="blue")
    print('hello')


entry_1 = Entry(screen)

label_3 = Label(screen, text="Password")

entry_2 = Entry(screen)



def login():
    label.config(text=int(entry_1.get()) + int(entry_2.get()))

button = Button(screen, text="Login", command=login)

entry_1.pack()
label_3.pack()
entry_2.pack()
button.pack(side="top")
screen.mainloop()

# %% [markdown]
# ### grid()
#
# Lệnh `grid()` sẽ giúp sắp xếp các đối tượng theo một bảng
#
# grid() có các tham số:
#
# - column : Tùy chọn này chỉ định số cột mà widget sẽ được đặt. Giá trị mặc định là 0
# - columnspan:  Dùng chỉ định số lượng cột mà widget sẽ được mở rộng
# - row: Tùy chọn này chỉ định số hàng cho widget sẽ được đặt .  Giá trị mặc định là 0
# - rowspan: Dùng chỉ định số lượng hàng mà widget sẽ được mở rộng
# - padx, pady: Dùng thể hiện pixel của padding được thêm vào bên ngoài đường viền widget . padx,  là phần padding theo chiều ngang, còn pady là phần padding theo chiều dọc.
# - ipadx, ipady : Dùng thể hiện pixel của padding được thêm vào bên trong đường viền widget. ipadx,  là phần padding theo chiều ngang, còn ipady là phần padding theo chiều dọc.
# - sticky : Được sử dụng trong điều kiện ô lớn hơn widget, được sử dụng chỉ định vị trí của widget bên trong ô. Nếu không sử dụng sticky, thì widget mặc định đặt ở giữa ô. Sticky có thể có các giá trị như N, E, S, W, NE, NW, SE & SW.

# %% [markdown]
# <b>Hãy ứng dụng lệnh grid() để xây dựng cửa sổ sau:</b>
#
# ![image.png](attachment:image.png)

# %%
from tkinter import *

screen = Tk()

screen.title("tk")
screen.geometry("500x200")

label_1 = Label(screen, text="hello")
label_2 = Label(screen, text="hello 2")
label_3 = Label(screen, text="hello 3")
label_4 = Label(screen, text="hello 4")
label_5 = Label(screen, text="hello 5")

label_1.grid(column=1, row=1)
label_2.grid(column=2, row=1)
label_3.grid(column=1, row=2)
label_4.grid(column=2, row=2)
label_5.grid(column=1, row=3, columnspan=2)

screen.mainloop()

# %%
from tkinter import *

username = []

def read_file():
    with open("username.csv", encoding="utf-8") as f:
        header = f.readline()
        user_name = f.readlines()

        header = header.strip()
        header = header.split(",")

    for i in range(len(user_name)):
        du_lieu = {}
        sv = user_name[i].strip()
        sv = sv.split(",")

        for j in range(len(sv)):
            du_lieu[header[j]] = sv[j]

        user_name[i] = du_lieu
    
    return user_name

username = read_file()
print(username)

def check_login(username, password):
    pass

def UI():
    screen = Tk()

    screen.title("Login Screen")
    screen.geometry("300x300")

    label_1 = Label(screen, text="Please enter email and password to login")
    label_2 = Label(screen, text="Username")
    label_3 = Label(screen, text="Password")
    result_label = Label(screen, text="")

    username_entry = Entry(screen)
    password_entry = Entry(screen, show="*")

    def login():
        pass

    button = Button(screen, text="Login", command=login)

    label_1.grid(column=2, row=1)
    label_2.grid(column=1, row=2)
    label_3.grid(column=1, row=3)
    username_entry.grid(column=2, row=2)
    password_entry.grid(column=2, row=3)
    button.grid(column=2, row=4)
    result_label.grid(column=2, row=5)

    screen.mainloop()

UI()
# Out:
# [{'username': 'tamdien', 'password': '123456'}, {'username': 'antran', 'password': '7890123'}, {'username': 'quangminh', 'password': '594823'}]

# %% [markdown]
# <b>Lập trình cho ứng dụng trên hoạt động:</b>
